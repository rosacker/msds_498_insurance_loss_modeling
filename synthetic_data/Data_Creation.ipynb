# %%
import random
import pandas as pd
import numpy as np

from data_generator.household import household

# %%
houses = [household() for i in range(10_000)]

# %%
result_df = pd.DataFrame([x.summary_with_debugging for x in houses if x.inforce])
result_df[['max_driver_hazard']].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
for x in houses:
  x.move_forward_n_years(random.randint(1, 30))

# %%
houses[2].move_forward_n_years(1)

houses[2].summary
# Out:
# {'inforce': True,
#  'household_tenure': 17,
#  'min_driver_tenure': 17,
#  'max_driver_tenure': 17,
#  'driver_count': 2,
#  'youthful_driver_count': 0,
#  'max_driver_age': 58,
#  'min_driver_age': 37,
#  'mean_driver_age': 47.5,
#  'credit_score': 660,
#  'multiline_houses': 1,
#  'multiline_rental': 0,
#  'multiline_personal_liability_umbrella': 1,
#  'multiline_personal_article_policy': 1,
#  'vehicle_info': [{'vehicle_age': 15,
#    'vehicle_years_owned': 0,
#    'vehicle_type': 'sedan',
#    'claim_cnt_all_1': 1,
#    'claim_cnt_all_2': 1,
#    'claim_cnt_all_3': 1,
#    'claim_cnt_all_4': 1,
#    'claim_cnt_all_5': 1,
#    'claim_cnt_all_6': 1,
#    'claim_cnt_all_7': 1,
#    'claim_cnt_all_8': 1,
#    'claim_cnt_all_9': 1,
#    'claim_cnt_all_10': 1,
#    'claim_cnt_all_11': 1,
#    'claim_cnt_all_12': 1,
#    'claim_cnt_all_13': 1,
#    'claim_cnt_all_14': 1,
#    'claim_cnt_all_15': 1,
#    'claim_cnt_bi_1': 0,
#    'claim_cnt_bi_2': 0,
#    'claim_cnt_bi_3': 0,
#    'claim_cnt_bi_4': 0,
#    'claim_cnt_bi_5': 0,
#    'claim_cnt_bi_6': 0,
#    'claim_cnt_bi_7': 0,
#    'claim_cnt_bi_8': 0,
#    'claim_cnt_bi_9': 0,
#    'claim_cnt_bi_10': 0,
#    'claim_cnt_bi_11': 0,
#    'claim_cnt_bi_12': 0,
#    'claim_cnt_bi_13': 0,
#    'claim_cnt_bi_14': 0,
#    'claim_cnt_bi_15': 0,
#    'claim_cnt_pd_1': 0,
#    'claim_cnt_pd_2': 0,
#    'claim_cnt_pd_3': 0,
#    'claim_cnt_pd_4': 0,
#    'claim_cnt_pd_5': 0,
#    'claim_cnt_pd_6': 0,
#    'claim_cnt_pd_7': 0,
#    'claim_cnt_pd_8': 0,
#    'claim_cnt_pd_9': 0,
#    'claim_cnt_pd_10': 0,
#    'claim_cnt_pd_11': 0,
#    'claim_cnt_pd_12': 0,
#    'claim_cnt_pd_13': 0,
#    'claim_cnt_pd_14': 0,
#    'claim_cnt_pd_15': 0,
#    'claim_cnt_coll_1': 0,
#    'claim_cnt_coll_2': 0,
#    'claim_cnt_coll_3': 0,
#    'claim_cnt_coll_4': 0,
#    'claim_cnt_coll_5': 0,
#    'claim_cnt_coll_6': 0,
#    'claim_cnt_coll_7': 0,
#    'claim_cnt_coll_8': 0,
#    'claim_cnt_coll_9': 0,
#    'claim_cnt_coll_10': 0,
#    'claim_cnt_coll_11': 0,
#    'claim_cnt_coll_12': 0,
#    'claim_cnt_coll_13': 0,
#    'claim_cnt_coll_14': 0,
#    'claim_cnt_coll_15': 0,
#    'claim_cnt_comp_1': 0,
#    'claim_cnt_comp_2': 0,
#    'claim_cnt_comp_3': 0,
#    'claim_cnt_comp_4': 0,
#    'claim_cnt_comp_5': 0,
#    'claim_cnt_comp_6': 0,
#    'claim_cnt_comp_7': 0,
#    'claim_cnt_comp_8': 0,
#    'claim_cnt_comp_9': 0,
#    'claim_cnt_comp_10': 0,
#    'claim_cnt_comp_11': 0,
#    'claim_cnt_comp_12': 0,
#    'claim_cnt_comp_13': 0,
#    'claim_cnt_comp_14': 0,
#    'claim_cnt_comp_15': 0,
#    'claim_cnt_ers_1': 1,
#    'claim_cnt_ers_2': 1,
#    'claim_cnt_ers_3': 1,
#    'claim_cnt_ers_4': 1,
#    'claim_cnt_ers_5': 1,
#    'claim_cnt_ers_6': 1,
#    'claim_cnt_ers_7': 1,
#    'claim_cnt_ers_8': 1,
#    'claim_cnt_ers_9': 1,
#    'claim_cnt_ers_10': 1,
#    'claim_cnt_ers_11': 1,
#    'claim_cnt_ers_12': 1,
#    'claim_cnt_ers_13': 1,
#    'claim_cnt_ers_14': 1,
#    'claim_cnt_ers_15': 1,
#    'claim_cnt_ubi_1': 0,
#    'claim_cnt_ubi_2': 0,
#    'claim_cnt_ubi_3': 0,
#    'claim_cnt_ubi_4': 0,
#    'claim_cnt_ubi_5': 0,
#    'claim_cnt_ubi_6': 0,
#    'claim_cnt_ubi_7': 0,
#    'claim_cnt_ubi_8': 0,
#    'claim_cnt_ubi_9': 0,
#    'claim_cnt_ubi_10': 0,
#    'claim_cnt_ubi_11': 0,
#    'claim_cnt_ubi_12': 0,
#    'claim_cnt_ubi_13': 0,
#    'claim_cnt_ubi_14': 0,
#    'claim_cnt_ubi_15': 0,
#    'claim_time_since_all': 1,
#    'claim_time_since_bi': None,
#    'claim_time_since_pd': None,
#    'claim_time_since_comp': None,
#    'claim_time_since_coll': None,
#    'claim_time_since_mpc': None,
#    'claim_time_since_ers': 1,
#    'claim_time_since_ubi': None}],
#  'driver_info': [{'driver_age': 58, 'driver_gender': 'm', 'driver_tenure': 17},
#   {'driver_age': 37, 'driver_gender': 'f', 'driver_tenure': 17}],
#  'claims_info': [{'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 17,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 16,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 15,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 14,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 13,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 12,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 11,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 10,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 9,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 8,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 7,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 6,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 5,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 4,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 3,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 2,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 1,
#    'driver_claim': True}],
#  'driver_cnt_16': 0,
#  'driver_cnt_17': 0,
#  'driver_cnt_18': 0,
#  'driver_cnt_19': 0,
#  'driver_cnt_20': 0,
#  'driver_cnt_21': 0,
#  'driver_cnt_22': 0,
#  'driver_cnt_23': 0,
#  'driver_cnt_24': 0,
#  'driver_cnt_25': 0,
#  'driver_cnt_26': 0,
#  'driver_cnt_27': 0,
#  'driver_cnt_28': 0,
#  'driver_cnt_29': 0,
#  'driver_cnt_30': 0,
#  'driver_cnt_31': 0,
#  'driver_cnt_32': 0,
#  'driver_cnt_33': 0,
#  'driver_cnt_34': 0,
#  'driver_cnt_35': 0,
#  'driver_cnt_36': 0,
#  'driver_cnt_37': 1,
#  'driver_cnt_38': 0,
#  'driver_cnt_39': 0,
#  'driver_cnt_40': 0,
#  'driver_cnt_41': 0,
#  'driver_cnt_42': 0,
#  'driver_cnt_43': 0,
#  'driver_cnt_44': 0,
#  'driver_cnt_45': 0,
#  'driver_cnt_46': 0,
#  'driver_cnt_47': 0,
#  'driver_cnt_48': 0,
#  'driver_cnt_49': 0,
#  'driver_cnt_50': 0,
#  'driver_cnt_51': 0,
#  'driver_cnt_52': 0,
#  'driver_cnt_53': 0,
#  'driver_cnt_54': 0,
#  'driver_cnt_55': 0,
#  'driver_cnt_56': 0,
#  'driver_cnt_57': 0,
#  'driver_cnt_58': 1,
#  'driver_cnt_59': 0,
#  'driver_cnt_60': 0,
#  'driver_cnt_61': 0,
#  'driver_cnt_62': 0,
#  'driver_cnt_63': 0,
#  'driver_cnt_64': 0,
#  'driver_cnt_65': 0,
#  'driver_cnt_66': 0,
#  'driver_cnt_67': 0,
#  'driver_cnt_68': 0,
#  'driver_cnt_69': 0,
#  'driver_cnt_70': 0,
#  'driver_cnt_71': 0,
#  'driver_cnt_72': 0,
#  'driver_cnt_73': 0,
#  'driver_cnt_74': 0,
#  'driver_cnt_75': 0,
#  'driver_cnt_76': 0,
#  'driver_cnt_77': 0,
#  'driver_cnt_78': 0,
#  'driver_cnt_79': 0,
#  'driver_cnt_80': 0,
#  'driver_cnt_81': 0,
#  'driver_cnt_82': 0,
#  'driver_cnt_83': 0,
#  'driver_cnt_84': 0,
#  'driver_cnt_85': 0,
#  'driver_cnt_86': 0,
#  'driver_cnt_87': 0,
#  'driver_cnt_88': 0,
#  'driver_cnt_89': 0,
#  'driver_cnt_90': 0,
#  'driver_cnt_91': 0,
#  'driver_cnt_92': 0,
#  'driver_cnt_93': 0,
#  'driver_cnt_94': 0,
#  'driver_cnt_95': 0,
#  'driver_cnt_96': 0,
#  'driver_cnt_97': 0,
#  'driver_cnt_98': 0,
#  'driver_cnt_16_m': 0,
#  'driver_cnt_16_f': 0,
#  'driver_cnt_17_m': 0,
#  'driver_cnt_17_f': 0,
#  'driver_cnt_18_m': 0,
#  'driver_cnt_18_f': 0,
#  'driver_cnt_19_m': 0,
#  'driver_cnt_19_f': 0,
#  'driver_cnt_20_m': 0,
#  'driver_cnt_20_f': 0,
#  'driver_cnt_21_m': 0,
#  'driver_cnt_21_f': 0,
#  'driver_cnt_22_m': 0,
#  'driver_cnt_22_f': 0,
#  'driver_cnt_23_m': 0,
#  'driver_cnt_23_f': 0,
#  'driver_cnt_24_m': 0,
#  'driver_cnt_24_f': 0,
#  'driver_cnt_25_m': 0,
#  'driver_cnt_25_f': 0,
#  'driver_cnt_26_m': 0,
#  'driver_cnt_26_f': 0,
#  'driver_cnt_27_m': 0,
#  'driver_cnt_27_f': 0,
#  'driver_cnt_28_m': 0,
#  'driver_cnt_28_f': 0,
#  'driver_cnt_29_m': 0,
#  'driver_cnt_29_f': 0,
#  'driver_cnt_30_m': 0,
#  'driver_cnt_30_f': 0,
#  'driver_cnt_31_m': 0,
#  'driver_cnt_31_f': 0,
#  'driver_cnt_32_m': 0,
#  'driver_cnt_32_f': 0,
#  'driver_cnt_33_m': 0,
#  'driver_cnt_33_f': 0,
#  'driver_cnt_34_m': 0,
#  'driver_cnt_34_f': 0,
#  'driver_cnt_35_m': 0,
#  'driver_cnt_35_f': 0,
#  'driver_cnt_36_m': 0,
#  'driver_cnt_36_f': 0,
#  'driver_cnt_37_m': 0,
#  'driver_cnt_37_f': 1,
#  'driver_cnt_38_m': 0,
#  'driver_cnt_38_f': 0,
#  'driver_cnt_39_m': 0,
#  'driver_cnt_39_f': 0,
#  'driver_cnt_40_m': 0,
#  'driver_cnt_40_f': 0,
#  'driver_cnt_41_m': 0,
#  'driver_cnt_41_f': 0,
#  'driver_cnt_42_m': 0,
#  'driver_cnt_42_f': 0,
#  'driver_cnt_43_m': 0,
#  'driver_cnt_43_f': 0,
#  'driver_cnt_44_m': 0,
#  'driver_cnt_44_f': 0,
#  'driver_cnt_45_m': 0,
#  'driver_cnt_45_f': 0,
#  'driver_cnt_46_m': 0,
#  'driver_cnt_46_f': 0,
#  'driver_cnt_47_m': 0,
#  'driver_cnt_47_f': 0,
#  'driver_cnt_48_m': 0,
#  'driver_cnt_48_f': 0,
#  'driver_cnt_49_m': 0,
#  'driver_cnt_49_f': 0,
#  'driver_cnt_50_m': 0,
#  'driver_cnt_50_f': 0,
#  'driver_cnt_51_m': 0,
#  'driver_cnt_51_f': 0,
#  'driver_cnt_52_m': 0,
#  'driver_cnt_52_f': 0,
#  'driver_cnt_53_m': 0,
#  'driver_cnt_53_f': 0,
#  'driver_cnt_54_m': 0,
#  'driver_cnt_54_f': 0,
#  'driver_cnt_55_m': 0,
#  'driver_cnt_55_f': 0,
#  'driver_cnt_56_m': 0,
#  'driver_cnt_56_f': 0,
#  'driver_cnt_57_m': 0,
#  'driver_cnt_57_f': 0,
#  'driver_cnt_58_m': 1,
#  'driver_cnt_58_f': 0,
#  'driver_cnt_59_m': 0,
#  'driver_cnt_59_f': 0,
#  'driver_cnt_60_m': 0,
#  'driver_cnt_60_f': 0,
#  'driver_cnt_61_m': 0,
#  'driver_cnt_61_f': 0,
#  'driver_cnt_62_m': 0,
#  'driver_cnt_62_f': 0,
#  'driver_cnt_63_m': 0,
#  'driver_cnt_63_f': 0,
#  'driver_cnt_64_m': 0,
#  'driver_cnt_64_f': 0,
#  'driver_cnt_65_m': 0,
#  'driver_cnt_65_f': 0,
#  'driver_cnt_66_m': 0,
#  'driver_cnt_66_f': 0,
#  'driver_cnt_67_m': 0,
#  'driver_cnt_67_f': 0,
#  'driver_cnt_68_m': 0,
#  'driver_cnt_68_f': 0,
#  'driver_cnt_69_m': 0,
#  'driver_cnt_69_f': 0,
#  'driver_cnt_70_m': 0,
#  'driver_cnt_70_f': 0,
#  'driver_cnt_71_m': 0,
#  'driver_cnt_71_f': 0,
#  'driver_cnt_72_m': 0,
#  'driver_cnt_72_f': 0,
#  'driver_cnt_73_m': 0,
#  'driver_cnt_73_f': 0,
#  'driver_cnt_74_m': 0,
#  'driver_cnt_74_f': 0,
#  'driver_cnt_75_m': 0,
#  'driver_cnt_75_f': 0,
#  'driver_cnt_76_m': 0,
#  'driver_cnt_76_f': 0,
#  'driver_cnt_77_m': 0,
#  'driver_cnt_77_f': 0,
#  'driver_cnt_78_m': 0,
#  'driver_cnt_78_f': 0,
#  'driver_cnt_79_m': 0,
#  'driver_cnt_79_f': 0,
#  'driver_cnt_80_m': 0,
#  'driver_cnt_80_f': 0,
#  'driver_cnt_81_m': 0,
#  'driver_cnt_81_f': 0,
#  'driver_cnt_82_m': 0,
#  'driver_cnt_82_f': 0,
#  'driver_cnt_83_m': 0,
#  'driver_cnt_83_f': 0,
#  'driver_cnt_84_m': 0,
#  'driver_cnt_84_f': 0,
#  'driver_cnt_85_m': 0,
#  'driver_cnt_85_f': 0,
#  'driver_cnt_86_m': 0,
#  'driver_cnt_86_f': 0,
#  'driver_cnt_87_m': 0,
#  'driver_cnt_87_f': 0,
#  'driver_cnt_88_m': 0,
#  'driver_cnt_88_f': 0,
#  'driver_cnt_89_m': 0,
#  'driver_cnt_89_f': 0,
#  'driver_cnt_90_m': 0,
#  'driver_cnt_90_f': 0,
#  'driver_cnt_91_m': 0,
#  'driver_cnt_91_f': 0,
#  'driver_cnt_92_m': 0,
#  'driver_cnt_92_f': 0,
#  'driver_cnt_93_m': 0,
#  'driver_cnt_93_f': 0,
#  'driver_cnt_94_m': 0,
#  'driver_cnt_94_f': 0,
#  'driver_cnt_95_m': 0,
#  'driver_cnt_95_f': 0,
#  'driver_cnt_96_m': 0,
#  'driver_cnt_96_f': 0,
#  'driver_cnt_97_m': 0,
#  'driver_cnt_97_f': 0,
#  'driver_cnt_98_m': 0,
#  'driver_cnt_98_f': 0,
#  'claim_cnt_all_1': 1,
#  'claim_cnt_all_2': 1,
#  'claim_cnt_all_3': 1,
#  'claim_cnt_all_4': 1,
#  'claim_cnt_all_5': 1,
#  'claim_cnt_all_6': 1,
#  'claim_cnt_all_7': 1,
#  'claim_cnt_all_8': 1,
#  'claim_cnt_all_9': 1,
#  'claim_cnt_all_10': 1,
#  'claim_cnt_all_11': 1,
#  'claim_cnt_all_12': 1,
#  'claim_cnt_all_13': 1,
#  'claim_cnt_all_14': 1,
#  'claim_cnt_all_15': 1,
#  'claim_cnt_bi_1': 0,
#  'claim_cnt_bi_2': 0,
#  'claim_cnt_bi_3': 0,
#  'claim_cnt_bi_4': 0,
#  'claim_cnt_bi_5': 0,
#  'claim_cnt_bi_6': 0,
#  'claim_cnt_bi_7': 0,
#  'claim_cnt_bi_8': 0,
#  'claim_cnt_bi_9': 0,
#  'claim_cnt_bi_10': 0,
#  'claim_cnt_bi_11': 0,
#  'claim_cnt_bi_12': 0,
#  'claim_cnt_bi_13': 0,
#  'claim_cnt_bi_14': 0,
#  'claim_cnt_bi_15': 0,
#  'claim_cnt_pd_1': 0,
#  'claim_cnt_pd_2': 0,
#  'claim_cnt_pd_3': 0,
#  'claim_cnt_pd_4': 0,
#  'claim_cnt_pd_5': 0,
#  'claim_cnt_pd_6': 0,
#  'claim_cnt_pd_7': 0,
#  'claim_cnt_pd_8': 0,
#  'claim_cnt_pd_9': 0,
#  'claim_cnt_pd_10': 0,
#  'claim_cnt_pd_11': 0,
#  'claim_cnt_pd_12': 0,
#  'claim_cnt_pd_13': 0,
#  'claim_cnt_pd_14': 0,
#  'claim_cnt_pd_15': 0,
#  'claim_cnt_coll_1': 0,
#  'claim_cnt_coll_2': 0,
#  'claim_cnt_coll_3': 0,
#  'claim_cnt_coll_4': 0,
#  'claim_cnt_coll_5': 0,
#  'claim_cnt_coll_6': 0,
#  'claim_cnt_coll_7': 0,
#  'claim_cnt_coll_8': 0,
#  'claim_cnt_coll_9': 0,
#  'claim_cnt_coll_10': 0,
#  'claim_cnt_coll_11': 0,
#  'claim_cnt_coll_12': 0,
#  'claim_cnt_coll_13': 0,
#  'claim_cnt_coll_14': 0,
#  'claim_cnt_coll_15': 0,
#  'claim_cnt_comp_1': 0,
#  'claim_cnt_comp_2': 0,
#  'claim_cnt_comp_3': 0,
#  'claim_cnt_comp_4': 0,
#  'claim_cnt_comp_5': 0,
#  'claim_cnt_comp_6': 0,
#  'claim_cnt_comp_7': 0,
#  'claim_cnt_comp_8': 0,
#  'claim_cnt_comp_9': 0,
#  'claim_cnt_comp_10': 0,
#  'claim_cnt_comp_11': 0,
#  'claim_cnt_comp_12': 0,
#  'claim_cnt_comp_13': 0,
#  'claim_cnt_comp_14': 0,
#  'claim_cnt_comp_15': 0,
#  'claim_cnt_ers_1': 1,
#  'claim_cnt_ers_2': 1,
#  'claim_cnt_ers_3': 1,
#  'claim_cnt_ers_4': 1,
#  'claim_cnt_ers_5': 1,
#  'claim_cnt_ers_6': 1,
#  'claim_cnt_ers_7': 1,
#  'claim_cnt_ers_8': 1,
#  'claim_cnt_ers_9': 1,
#  'claim_cnt_ers_10': 1,
#  'claim_cnt_ers_11': 1,
#  'claim_cnt_ers_12': 1,
#  'claim_cnt_ers_13': 1,
#  'claim_cnt_ers_14': 1,
#  'claim_cnt_ers_15': 1,
#  'claim_cnt_ubi_1': 0,
#  'claim_cnt_ubi_2': 0,
#  'claim_cnt_ubi_3': 0,
#  'claim_cnt_ubi_4': 0,
#  'claim_cnt_ubi_5': 0,
#  'claim_cnt_ubi_6': 0,
#  'claim_cnt_ubi_7': 0,
#  'claim_cnt_ubi_8': 0,
#  'claim_cnt_ubi_9': 0,
#  'claim_cnt_ubi_10': 0,
#  'claim_cnt_ubi_11': 0,
#  'claim_cnt_ubi_12': 0,
#  'claim_cnt_ubi_13': 0,
#  'claim_cnt_ubi_14': 0,
#  'claim_cnt_ubi_15': 0,
#  'claim_time_since_all': 1,
#  'claim_time_since_bi': None,
#  'claim_time_since_pd': None,
#  'claim_time_since_comp': None,
#  'claim_time_since_coll': None,
#  'claim_time_since_mpc': None,
#  'claim_time_since_ers': 1,
#  'claim_time_since_ubi': None}

# %%
result_df = pd.DataFrame([x.summary_with_debugging for x in houses if x.inforce])
result_df[['mean_driver_hazard']].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
result_df.plot.scatter(x = 'min_driver_age', y = 'max_driver_hazard')
# Out:
# <Axes: xlabel='min_driver_age', ylabel='max_driver_hazard'>

# %%
my_house = household()
my_house.child_count
# Out:
# 0

# %%
my_house.claims
# Out:
# []

# %%
my_house.move_forward_n_years(12)

# %%
my_house.summary
# Out:
# {'inforce': True,
#  'household_tenure': 12,
#  'min_driver_tenure': 12,
#  'max_driver_tenure': 12,
#  'driver_count': 2,
#  'youthful_driver_count': 0,
#  'max_driver_age': 64,
#  'min_driver_age': 35,
#  'mean_driver_age': 49.5,
#  'credit_score': 722,
#  'multiline_houses': 1,
#  'multiline_rental': 0,
#  'multiline_personal_liability_umbrella': 0,
#  'multiline_personal_article_policy': 0,
#  'vehicle_info': [{'vehicle_age': 15,
#    'vehicle_years_owned': 0,
#    'vehicle_type': 'sedan',
#    'claim_cnt_all_1': 1,
#    'claim_cnt_all_2': 1,
#    'claim_cnt_all_3': 1,
#    'claim_cnt_all_4': 1,
#    'claim_cnt_all_5': 1,
#    'claim_cnt_all_6': 1,
#    'claim_cnt_all_7': 1,
#    'claim_cnt_all_8': 1,
#    'claim_cnt_all_9': 1,
#    'claim_cnt_all_10': 1,
#    'claim_cnt_all_11': 1,
#    'claim_cnt_all_12': 1,
#    'claim_cnt_all_13': 0,
#    'claim_cnt_all_14': 0,
#    'claim_cnt_all_15': 0,
#    'claim_cnt_bi_1': 0,
#    'claim_cnt_bi_2': 0,
#    'claim_cnt_bi_3': 0,
#    'claim_cnt_bi_4': 0,
#    'claim_cnt_bi_5': 0,
#    'claim_cnt_bi_6': 0,
#    'claim_cnt_bi_7': 0,
#    'claim_cnt_bi_8': 0,
#    'claim_cnt_bi_9': 0,
#    'claim_cnt_bi_10': 0,
#    'claim_cnt_bi_11': 0,
#    'claim_cnt_bi_12': 0,
#    'claim_cnt_bi_13': 0,
#    'claim_cnt_bi_14': 0,
#    'claim_cnt_bi_15': 0,
#    'claim_cnt_pd_1': 0,
#    'claim_cnt_pd_2': 0,
#    'claim_cnt_pd_3': 0,
#    'claim_cnt_pd_4': 0,
#    'claim_cnt_pd_5': 0,
#    'claim_cnt_pd_6': 0,
#    'claim_cnt_pd_7': 0,
#    'claim_cnt_pd_8': 0,
#    'claim_cnt_pd_9': 0,
#    'claim_cnt_pd_10': 0,
#    'claim_cnt_pd_11': 0,
#    'claim_cnt_pd_12': 0,
#    'claim_cnt_pd_13': 0,
#    'claim_cnt_pd_14': 0,
#    'claim_cnt_pd_15': 0,
#    'claim_cnt_coll_1': 0,
#    'claim_cnt_coll_2': 0,
#    'claim_cnt_coll_3': 0,
#    'claim_cnt_coll_4': 0,
#    'claim_cnt_coll_5': 0,
#    'claim_cnt_coll_6': 0,
#    'claim_cnt_coll_7': 0,
#    'claim_cnt_coll_8': 0,
#    'claim_cnt_coll_9': 0,
#    'claim_cnt_coll_10': 0,
#    'claim_cnt_coll_11': 0,
#    'claim_cnt_coll_12': 0,
#    'claim_cnt_coll_13': 0,
#    'claim_cnt_coll_14': 0,
#    'claim_cnt_coll_15': 0,
#    'claim_cnt_comp_1': 0,
#    'claim_cnt_comp_2': 0,
#    'claim_cnt_comp_3': 0,
#    'claim_cnt_comp_4': 0,
#    'claim_cnt_comp_5': 0,
#    'claim_cnt_comp_6': 0,
#    'claim_cnt_comp_7': 0,
#    'claim_cnt_comp_8': 0,
#    'claim_cnt_comp_9': 0,
#    'claim_cnt_comp_10': 0,
#    'claim_cnt_comp_11': 0,
#    'claim_cnt_comp_12': 0,
#    'claim_cnt_comp_13': 0,
#    'claim_cnt_comp_14': 0,
#    'claim_cnt_comp_15': 0,
#    'claim_cnt_ers_1': 1,
#    'claim_cnt_ers_2': 1,
#    'claim_cnt_ers_3': 1,
#    'claim_cnt_ers_4': 1,
#    'claim_cnt_ers_5': 1,
#    'claim_cnt_ers_6': 1,
#    'claim_cnt_ers_7': 1,
#    'claim_cnt_ers_8': 1,
#    'claim_cnt_ers_9': 1,
#    'claim_cnt_ers_10': 1,
#    'claim_cnt_ers_11': 1,
#    'claim_cnt_ers_12': 1,
#    'claim_cnt_ers_13': 0,
#    'claim_cnt_ers_14': 0,
#    'claim_cnt_ers_15': 0,
#    'claim_cnt_ubi_1': 0,
#    'claim_cnt_ubi_2': 0,
#    'claim_cnt_ubi_3': 0,
#    'claim_cnt_ubi_4': 0,
#    'claim_cnt_ubi_5': 0,
#    'claim_cnt_ubi_6': 0,
#    'claim_cnt_ubi_7': 0,
#    'claim_cnt_ubi_8': 0,
#    'claim_cnt_ubi_9': 0,
#    'claim_cnt_ubi_10': 0,
#    'claim_cnt_ubi_11': 0,
#    'claim_cnt_ubi_12': 0,
#    'claim_cnt_ubi_13': 0,
#    'claim_cnt_ubi_14': 0,
#    'claim_cnt_ubi_15': 0,
#    'claim_time_since_all': 1,
#    'claim_time_since_bi': None,
#    'claim_time_since_pd': None,
#    'claim_time_since_comp': None,
#    'claim_time_since_coll': None,
#    'claim_time_since_mpc': None,
#    'claim_time_since_ers': 1,
#    'claim_time_since_ubi': None}],
#  'driver_info': [{'driver_age': 64, 'driver_gender': 'm', 'driver_tenure': 12},
#   {'driver_age': 35, 'driver_gender': 'f', 'driver_tenure': 12}],
#  'claims_info': [{'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 12,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 11,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 10,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 9,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 8,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 7,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 6,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 5,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 4,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 3,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 2,
#    'driver_claim': True},
#   {'bi_ind': 0,
#    'pd_ind': 0,
#    'coll_ind': 0,
#    'comp_ind': 0,
#    'mpc_ind': 0,
#    'ers_ind': 1,
#    'ubi_ind': 0,
#    'claim_age': 1,
#    'driver_claim': True}],
#  'driver_cnt_16': 0,
#  'driver_cnt_17': 0,
#  'driver_cnt_18': 0,
#  'driver_cnt_19': 0,
#  'driver_cnt_20': 0,
#  'driver_cnt_21': 0,
#  'driver_cnt_22': 0,
#  'driver_cnt_23': 0,
#  'driver_cnt_24': 0,
#  'driver_cnt_25': 0,
#  'driver_cnt_26': 0,
#  'driver_cnt_27': 0,
#  'driver_cnt_28': 0,
#  'driver_cnt_29': 0,
#  'driver_cnt_30': 0,
#  'driver_cnt_31': 0,
#  'driver_cnt_32': 0,
#  'driver_cnt_33': 0,
#  'driver_cnt_34': 0,
#  'driver_cnt_35': 1,
#  'driver_cnt_36': 0,
#  'driver_cnt_37': 0,
#  'driver_cnt_38': 0,
#  'driver_cnt_39': 0,
#  'driver_cnt_40': 0,
#  'driver_cnt_41': 0,
#  'driver_cnt_42': 0,
#  'driver_cnt_43': 0,
#  'driver_cnt_44': 0,
#  'driver_cnt_45': 0,
#  'driver_cnt_46': 0,
#  'driver_cnt_47': 0,
#  'driver_cnt_48': 0,
#  'driver_cnt_49': 0,
#  'driver_cnt_50': 0,
#  'driver_cnt_51': 0,
#  'driver_cnt_52': 0,
#  'driver_cnt_53': 0,
#  'driver_cnt_54': 0,
#  'driver_cnt_55': 0,
#  'driver_cnt_56': 0,
#  'driver_cnt_57': 0,
#  'driver_cnt_58': 0,
#  'driver_cnt_59': 0,
#  'driver_cnt_60': 0,
#  'driver_cnt_61': 0,
#  'driver_cnt_62': 0,
#  'driver_cnt_63': 0,
#  'driver_cnt_64': 1,
#  'driver_cnt_65': 0,
#  'driver_cnt_66': 0,
#  'driver_cnt_67': 0,
#  'driver_cnt_68': 0,
#  'driver_cnt_69': 0,
#  'driver_cnt_70': 0,
#  'driver_cnt_71': 0,
#  'driver_cnt_72': 0,
#  'driver_cnt_73': 0,
#  'driver_cnt_74': 0,
#  'driver_cnt_75': 0,
#  'driver_cnt_76': 0,
#  'driver_cnt_77': 0,
#  'driver_cnt_78': 0,
#  'driver_cnt_79': 0,
#  'driver_cnt_80': 0,
#  'driver_cnt_81': 0,
#  'driver_cnt_82': 0,
#  'driver_cnt_83': 0,
#  'driver_cnt_84': 0,
#  'driver_cnt_85': 0,
#  'driver_cnt_86': 0,
#  'driver_cnt_87': 0,
#  'driver_cnt_88': 0,
#  'driver_cnt_89': 0,
#  'driver_cnt_90': 0,
#  'driver_cnt_91': 0,
#  'driver_cnt_92': 0,
#  'driver_cnt_93': 0,
#  'driver_cnt_94': 0,
#  'driver_cnt_95': 0,
#  'driver_cnt_96': 0,
#  'driver_cnt_97': 0,
#  'driver_cnt_98': 0,
#  'driver_cnt_16_m': 0,
#  'driver_cnt_16_f': 0,
#  'driver_cnt_17_m': 0,
#  'driver_cnt_17_f': 0,
#  'driver_cnt_18_m': 0,
#  'driver_cnt_18_f': 0,
#  'driver_cnt_19_m': 0,
#  'driver_cnt_19_f': 0,
#  'driver_cnt_20_m': 0,
#  'driver_cnt_20_f': 0,
#  'driver_cnt_21_m': 0,
#  'driver_cnt_21_f': 0,
#  'driver_cnt_22_m': 0,
#  'driver_cnt_22_f': 0,
#  'driver_cnt_23_m': 0,
#  'driver_cnt_23_f': 0,
#  'driver_cnt_24_m': 0,
#  'driver_cnt_24_f': 0,
#  'driver_cnt_25_m': 0,
#  'driver_cnt_25_f': 0,
#  'driver_cnt_26_m': 0,
#  'driver_cnt_26_f': 0,
#  'driver_cnt_27_m': 0,
#  'driver_cnt_27_f': 0,
#  'driver_cnt_28_m': 0,
#  'driver_cnt_28_f': 0,
#  'driver_cnt_29_m': 0,
#  'driver_cnt_29_f': 0,
#  'driver_cnt_30_m': 0,
#  'driver_cnt_30_f': 0,
#  'driver_cnt_31_m': 0,
#  'driver_cnt_31_f': 0,
#  'driver_cnt_32_m': 0,
#  'driver_cnt_32_f': 0,
#  'driver_cnt_33_m': 0,
#  'driver_cnt_33_f': 0,
#  'driver_cnt_34_m': 0,
#  'driver_cnt_34_f': 0,
#  'driver_cnt_35_m': 0,
#  'driver_cnt_35_f': 1,
#  'driver_cnt_36_m': 0,
#  'driver_cnt_36_f': 0,
#  'driver_cnt_37_m': 0,
#  'driver_cnt_37_f': 0,
#  'driver_cnt_38_m': 0,
#  'driver_cnt_38_f': 0,
#  'driver_cnt_39_m': 0,
#  'driver_cnt_39_f': 0,
#  'driver_cnt_40_m': 0,
#  'driver_cnt_40_f': 0,
#  'driver_cnt_41_m': 0,
#  'driver_cnt_41_f': 0,
#  'driver_cnt_42_m': 0,
#  'driver_cnt_42_f': 0,
#  'driver_cnt_43_m': 0,
#  'driver_cnt_43_f': 0,
#  'driver_cnt_44_m': 0,
#  'driver_cnt_44_f': 0,
#  'driver_cnt_45_m': 0,
#  'driver_cnt_45_f': 0,
#  'driver_cnt_46_m': 0,
#  'driver_cnt_46_f': 0,
#  'driver_cnt_47_m': 0,
#  'driver_cnt_47_f': 0,
#  'driver_cnt_48_m': 0,
#  'driver_cnt_48_f': 0,
#  'driver_cnt_49_m': 0,
#  'driver_cnt_49_f': 0,
#  'driver_cnt_50_m': 0,
#  'driver_cnt_50_f': 0,
#  'driver_cnt_51_m': 0,
#  'driver_cnt_51_f': 0,
#  'driver_cnt_52_m': 0,
#  'driver_cnt_52_f': 0,
#  'driver_cnt_53_m': 0,
#  'driver_cnt_53_f': 0,
#  'driver_cnt_54_m': 0,
#  'driver_cnt_54_f': 0,
#  'driver_cnt_55_m': 0,
#  'driver_cnt_55_f': 0,
#  'driver_cnt_56_m': 0,
#  'driver_cnt_56_f': 0,
#  'driver_cnt_57_m': 0,
#  'driver_cnt_57_f': 0,
#  'driver_cnt_58_m': 0,
#  'driver_cnt_58_f': 0,
#  'driver_cnt_59_m': 0,
#  'driver_cnt_59_f': 0,
#  'driver_cnt_60_m': 0,
#  'driver_cnt_60_f': 0,
#  'driver_cnt_61_m': 0,
#  'driver_cnt_61_f': 0,
#  'driver_cnt_62_m': 0,
#  'driver_cnt_62_f': 0,
#  'driver_cnt_63_m': 0,
#  'driver_cnt_63_f': 0,
#  'driver_cnt_64_m': 1,
#  'driver_cnt_64_f': 0,
#  'driver_cnt_65_m': 0,
#  'driver_cnt_65_f': 0,
#  'driver_cnt_66_m': 0,
#  'driver_cnt_66_f': 0,
#  'driver_cnt_67_m': 0,
#  'driver_cnt_67_f': 0,
#  'driver_cnt_68_m': 0,
#  'driver_cnt_68_f': 0,
#  'driver_cnt_69_m': 0,
#  'driver_cnt_69_f': 0,
#  'driver_cnt_70_m': 0,
#  'driver_cnt_70_f': 0,
#  'driver_cnt_71_m': 0,
#  'driver_cnt_71_f': 0,
#  'driver_cnt_72_m': 0,
#  'driver_cnt_72_f': 0,
#  'driver_cnt_73_m': 0,
#  'driver_cnt_73_f': 0,
#  'driver_cnt_74_m': 0,
#  'driver_cnt_74_f': 0,
#  'driver_cnt_75_m': 0,
#  'driver_cnt_75_f': 0,
#  'driver_cnt_76_m': 0,
#  'driver_cnt_76_f': 0,
#  'driver_cnt_77_m': 0,
#  'driver_cnt_77_f': 0,
#  'driver_cnt_78_m': 0,
#  'driver_cnt_78_f': 0,
#  'driver_cnt_79_m': 0,
#  'driver_cnt_79_f': 0,
#  'driver_cnt_80_m': 0,
#  'driver_cnt_80_f': 0,
#  'driver_cnt_81_m': 0,
#  'driver_cnt_81_f': 0,
#  'driver_cnt_82_m': 0,
#  'driver_cnt_82_f': 0,
#  'driver_cnt_83_m': 0,
#  'driver_cnt_83_f': 0,
#  'driver_cnt_84_m': 0,
#  'driver_cnt_84_f': 0,
#  'driver_cnt_85_m': 0,
#  'driver_cnt_85_f': 0,
#  'driver_cnt_86_m': 0,
#  'driver_cnt_86_f': 0,
#  'driver_cnt_87_m': 0,
#  'driver_cnt_87_f': 0,
#  'driver_cnt_88_m': 0,
#  'driver_cnt_88_f': 0,
#  'driver_cnt_89_m': 0,
#  'driver_cnt_89_f': 0,
#  'driver_cnt_90_m': 0,
#  'driver_cnt_90_f': 0,
#  'driver_cnt_91_m': 0,
#  'driver_cnt_91_f': 0,
#  'driver_cnt_92_m': 0,
#  'driver_cnt_92_f': 0,
#  'driver_cnt_93_m': 0,
#  'driver_cnt_93_f': 0,
#  'driver_cnt_94_m': 0,
#  'driver_cnt_94_f': 0,
#  'driver_cnt_95_m': 0,
#  'driver_cnt_95_f': 0,
#  'driver_cnt_96_m': 0,
#  'driver_cnt_96_f': 0,
#  'driver_cnt_97_m': 0,
#  'driver_cnt_97_f': 0,
#  'driver_cnt_98_m': 0,
#  'driver_cnt_98_f': 0,
#  'claim_cnt_all_1': 1,
#  'claim_cnt_all_2': 1,
#  'claim_cnt_all_3': 1,
#  'claim_cnt_all_4': 1,
#  'claim_cnt_all_5': 1,
#  'claim_cnt_all_6': 1,
#  'claim_cnt_all_7': 1,
#  'claim_cnt_all_8': 1,
#  'claim_cnt_all_9': 1,
#  'claim_cnt_all_10': 1,
#  'claim_cnt_all_11': 1,
#  'claim_cnt_all_12': 1,
#  'claim_cnt_all_13': 0,
#  'claim_cnt_all_14': 0,
#  'claim_cnt_all_15': 0,
#  'claim_cnt_bi_1': 0,
#  'claim_cnt_bi_2': 0,
#  'claim_cnt_bi_3': 0,
#  'claim_cnt_bi_4': 0,
#  'claim_cnt_bi_5': 0,
#  'claim_cnt_bi_6': 0,
#  'claim_cnt_bi_7': 0,
#  'claim_cnt_bi_8': 0,
#  'claim_cnt_bi_9': 0,
#  'claim_cnt_bi_10': 0,
#  'claim_cnt_bi_11': 0,
#  'claim_cnt_bi_12': 0,
#  'claim_cnt_bi_13': 0,
#  'claim_cnt_bi_14': 0,
#  'claim_cnt_bi_15': 0,
#  'claim_cnt_pd_1': 0,
#  'claim_cnt_pd_2': 0,
#  'claim_cnt_pd_3': 0,
#  'claim_cnt_pd_4': 0,
#  'claim_cnt_pd_5': 0,
#  'claim_cnt_pd_6': 0,
#  'claim_cnt_pd_7': 0,
#  'claim_cnt_pd_8': 0,
#  'claim_cnt_pd_9': 0,
#  'claim_cnt_pd_10': 0,
#  'claim_cnt_pd_11': 0,
#  'claim_cnt_pd_12': 0,
#  'claim_cnt_pd_13': 0,
#  'claim_cnt_pd_14': 0,
#  'claim_cnt_pd_15': 0,
#  'claim_cnt_coll_1': 0,
#  'claim_cnt_coll_2': 0,
#  'claim_cnt_coll_3': 0,
#  'claim_cnt_coll_4': 0,
#  'claim_cnt_coll_5': 0,
#  'claim_cnt_coll_6': 0,
#  'claim_cnt_coll_7': 0,
#  'claim_cnt_coll_8': 0,
#  'claim_cnt_coll_9': 0,
#  'claim_cnt_coll_10': 0,
#  'claim_cnt_coll_11': 0,
#  'claim_cnt_coll_12': 0,
#  'claim_cnt_coll_13': 0,
#  'claim_cnt_coll_14': 0,
#  'claim_cnt_coll_15': 0,
#  'claim_cnt_comp_1': 0,
#  'claim_cnt_comp_2': 0,
#  'claim_cnt_comp_3': 0,
#  'claim_cnt_comp_4': 0,
#  'claim_cnt_comp_5': 0,
#  'claim_cnt_comp_6': 0,
#  'claim_cnt_comp_7': 0,
#  'claim_cnt_comp_8': 0,
#  'claim_cnt_comp_9': 0,
#  'claim_cnt_comp_10': 0,
#  'claim_cnt_comp_11': 0,
#  'claim_cnt_comp_12': 0,
#  'claim_cnt_comp_13': 0,
#  'claim_cnt_comp_14': 0,
#  'claim_cnt_comp_15': 0,
#  'claim_cnt_ers_1': 1,
#  'claim_cnt_ers_2': 1,
#  'claim_cnt_ers_3': 1,
#  'claim_cnt_ers_4': 1,
#  'claim_cnt_ers_5': 1,
#  'claim_cnt_ers_6': 1,
#  'claim_cnt_ers_7': 1,
#  'claim_cnt_ers_8': 1,
#  'claim_cnt_ers_9': 1,
#  'claim_cnt_ers_10': 1,
#  'claim_cnt_ers_11': 1,
#  'claim_cnt_ers_12': 1,
#  'claim_cnt_ers_13': 0,
#  'claim_cnt_ers_14': 0,
#  'claim_cnt_ers_15': 0,
#  'claim_cnt_ubi_1': 0,
#  'claim_cnt_ubi_2': 0,
#  'claim_cnt_ubi_3': 0,
#  'claim_cnt_ubi_4': 0,
#  'claim_cnt_ubi_5': 0,
#  'claim_cnt_ubi_6': 0,
#  'claim_cnt_ubi_7': 0,
#  'claim_cnt_ubi_8': 0,
#  'claim_cnt_ubi_9': 0,
#  'claim_cnt_ubi_10': 0,
#  'claim_cnt_ubi_11': 0,
#  'claim_cnt_ubi_12': 0,
#  'claim_cnt_ubi_13': 0,
#  'claim_cnt_ubi_14': 0,
#  'claim_cnt_ubi_15': 0,
#  'claim_time_since_all': 1,
#  'claim_time_since_bi': None,
#  'claim_time_since_pd': None,
#  'claim_time_since_comp': None,
#  'claim_time_since_coll': None,
#  'claim_time_since_mpc': None,
#  'claim_time_since_ers': 1,
#  'claim_time_since_ubi': None}

# %%
for i in range(50):
  print(f"Year: {i+1}")
  my_house.move_forward_n_years(1)
  #print(my_house.child_count)
  print(my_house.inforce)
  print(my_house.tenure_years)
  print("")
# Out:
# Year: 1
# True
# 13
#
# Year: 2
# True
# 14
#
# Year: 3
# True
# 15
#
# Year: 4
# True
# 16
#
# Year: 5
# True
# 17
#
# Year: 6
# True
# 18
#
# Year: 7
# True
# 19
#
# Year: 8
# True
# 20
#
# Year: 9
# True
# 21
#
# Year: 10
# True
# 22
#
# Year: 11
# True
# 23
#
# Year: 12
# True
# 24
#
# Year: 13
# True
# 25
#
# Year: 14
# True
# 26
#
# Year: 15
# True
# 27
#
# Year: 16
# False
# 28
#
# Year: 17
# False
# 28
#
# Year: 18
# False
# 28
#
# Year: 19
# False
# 28
#
# Year: 20
# False
# 28
#
# Year: 21
# False
# 28
#
# Year: 22
# False
# 28
#
# Year: 23
# False
# 28
#
# Year: 24
# False
# 28
#
# Year: 25
# False
# 28
#
# Year: 26
# False
# 28
#
# Year: 27
# False
# 28
#
# Year: 28
# False
# 28
#
# Year: 29
# False
# 28
#
# Year: 30
# False
# 28
#
# Year: 31
# False
# 28
#
# Year: 32
# False
# 28
#
# Year: 33
# False
# 28
#
# Year: 34
# False
# 28
#
# Year: 35
# False
# 28
#
# Year: 36
# False
# 28
#
# Year: 37
# False
# 28
#
# Year: 38
# False
# 28
#
# Year: 39
# False
# 28
#
# Year: 40
# False
# 28
#
# Year: 41
# False
# 28
#
# Year: 42
# False
# 28
#
# Year: 43
# False
# 28
#
# Year: 44
# False
# 28
#
# Year: 45
# False
# 28
#
# Year: 46
# False
# 28
#
# Year: 47
# False
# 28
#
# Year: 48
# False
# 28
#
# Year: 49
# False
# 28
#
# Year: 50
# False
# 28

# %%
[x.tenure_years for x in my_house.drivers]

# %%
for x in my_house.drivers:
    x.tenure_years += 1
